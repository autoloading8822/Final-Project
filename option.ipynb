# %% [markdown]
# # Compression with Constraints: Steganography
#
# The natural images are compressible, usually a full size image of several megabytes can be reduced to kilobytes level easily without lossing too much important information. Such property has been used widely to denoising, deblur, etc. techniques.
#
# The [``steganography``](https://en.wikipedia.org/wiki/Steganography) is a topic lying in the cryptography. It is concealing a file, message, image, or video within another file, message, image, or video.
#
# The advantage of steganography over cryptography alone is that the intended secret message ***does not attract attention to itself as an object of scrutiny***. Plainly visible encrypted messages, no matter how unbreakable they are, arouse interest and may in themselves be incriminating in countries in which encryption is illegal.
#
# Whereas cryptography is the practice of protecting the contents of a message alone, steganography is concerned both with concealing the fact that a secret message is being sent and its contents.
#
# Steganography includes the concealment of information within computer files. In digital steganography, electronic communications may include steganographic coding inside of a transport layer, such as a document file, image file, program or protocol. Media files are ideal for steganographic transmission because of their large size. For example, a sender might start with an innocuous image file and adjust the color of every hundredth pixel to correspond to a letter in the alphabet. The change is so subtle that someone who is not specifically looking for it is unlikely to notice the change.
#
# In this project, we deal with a special case: stegranography with images only. So unlike many practical scenes, for instance, encrypt text, document in images, this task might not be able to produce perfect recovery of information.

# %% [markdown]
# ## Purpose of the project
#
# The project is not meant to create super powerful technique to conceal information, it is more concerned to get used to imaging processing libraries and optimization techniques. On the other hand, it also provides a challenge to think about how to detect the ``steganographic`` images without the original images.

# %% [markdown]
# ## Mathematical aspects
#
# The stegranography has two important components: encryption and decryption.
#
# Suppose you have an original image and a secret image.
#
#
# 1.   Encryption: As a sender, your task is to make the original image and secret image merge into one image. The purpose is two fold. Firstly, your outcome must be an image, if this image stays far away from the original image, then it will attract other people's attention. That will count as a failure. Secondly, your outcome image must also convey the information of the secret image. It is not that simple, since any blending of information will change each other. The problem is how much we can afford.
# 2.   Decryption: After the encryption part, your outcome image will have two parts of information coming from original image and the secret image. As the receiver, your task will be inverting the encryption process, to recover the secret image as much as possible (Caution,  the receiver do not care about original image).
#
# If we mathematically represent such process, let $x$ be the original image, $y$ is the secret image, then $z = E(x, y)$ is the encrypted image, $E$ is the encryption function. You will try to minimize
# $$\|z - x\|$$
# The above norm is in certain sense, we will discuss that later. However, above minimization will subject to another constraint, which is the decryption function $D$ can recover sufficient information of the secret image. That is
# $$\|D(z) - y\|$$
# should be as small as possible.
#
# It is possible to construct a unified objective function:
# $$\min_{E, D} \|x - E(x,y)\| + \gamma \|y - D(z)\|$$
# where $E$ and $D$ are the parameters to find. $\gamma$ is a parameter chosen at your choice.
#
# Of course, there are other constraints from the images, because images are pixels, each pixel contains 3 channels: R,G,B, each one is a 8-bit integer, goes from 0 to 255. If the image has 4 channels RGBA, then it will provide more information. Therefore above optimization problem also has constraints that $E(x,y)$ and $D(z)$ must be images.

# %% [markdown]
# ## Algorithm 101, LSB
#
# The LSB is called least significant bits, which means you will replace the least significant bits of the original image with the secret image's most significant bits. This method will kill some information from both images, but the performance seems OK for general cases.
#
# Here are a few references on this simple algorithm:
#
# 0.   https://towardsdatascience.com/steganography-hiding-an-image-inside-another-77ca66b2acb1, the code is [here](https://github.com/kelvins/steganography)
# 1.   https://github.com/RobinDavid/LSB-Steganography
# 2.   https://pdfs.semanticscholar.org/3dce/b6307cee042b687b7f377ec1d5de91ce20b0.pdf
# 3.   https://hackernoon.com/simple-image-steganography-in-python-18c7b534854f
#
# The basic idea is (suppose you have a code to turn int8 into binary string),  inside each channel, say R, your original image's pixel, say represented as ``1001,0011``, and your secret image's that pixel is ``1110,1101``, then replace the last 4 bits in original image's pixel with the first 4 bits of secret image's corresponding pixel, the resulting number will be ``1001,1110``. In this way, the change in the original image could be small (on average).  There are other ways to alter the LSB, like treating the secret image as a binary string , and evenly distribute to each pixel. ***In our case, for simplicity, we only consider the images with the same size.***

# %% [markdown]
# ## Shortcomings
#
# The shortcomings of algorithms/methods are mainly on the detection, which is, we can easily detect your outcome image is not feeling right.
#
# In practice, if you look at the altered image, say from LSB, you do not feel anything. But the LSB has a very obvious drawback: it alters the last bit, which may distory the statistics of the last bit. In theory, the last bit 0 and 1 should obey certain heuristic distribution in the image, but now it will be changed.
#
# The detection code is here: https://github.com/b3dk7/StegExpose
#
# In https://dl.acm.org/citation.cfm?id=1929317, the paper introduced the method to preserve the statistics.
#
# In https://pdfs.semanticscholar.org/80a5/fcbeda7697d9641bc80460593c2f8f305a65.pdf, it introduced the detection of LSB.
#
#
# In http://futuremedia.szu.edu.cn/assets/files/CF_What%20makes%20the%20stego%20imageundetectable.pdf, the authors considered choosing the best original image to hide the given secret image
#
# Again,  currently, we are not supposed to consider this far, but it will be a future work if you find this interesting.

# %% [markdown]
# ## Other ways
#
# The review paper (maybe old) is found here: https://www.sciencedirect.com/science/article/pii/B9780123855107000023
#
# (some other reviews are found: [here](https://pdfs.semanticscholar.org/57a1/d15dcbf946f093a59db55f8828699fef7826.pdf) and [here](https://www.cscjournals.org/manuscript/Journals/IJCSS/Volume6/Issue3/IJCSS-670.pdf))
#
#
# 1.   https://arxiv.org/pdf/1606.05294.pdf. In this paper, it introduces the method to use NN to replace (learn) the LSB process.
# 2.   https://papers.nips.cc/paper/6802-hiding-images-in-plain-sight-deep-steganography.pdf, it introduced a NN to  approximate $D$ and $E$.
# 3. http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.178.7157&rep=rep1&type=pdf, it uses the DCT (discrete-cosine-transform) and LSB.
# 4. https://arxiv.org/pdf/1806.06357.pdf and  [code](https://github.com/adamcavendish/Deep-Image-Steganography)
# 5. https://ieeexplore.ieee.org/document/8403208/all-figures
# 6. https://eccv2018.org/openaccess/content_ECCV_2018/papers/Jiren_Zhu_HiDDeN_Hiding_Data_ECCV_2018_paper.pdf
# 7. https://arxiv.org/pdf/1904.01444.pdf
# 8. https://link.springer.com/article/10.1007/s00521-014-1702-1

# %% [markdown]
# ## First task
# Implement LSB, the images (orignal and secret) are of the same sizes. If you do not want to implement any, at least go through the code  [here](https://github.com/kelvins/steganography).

# %% [markdown]
# ## Second task
# Try to use neural network to approximate $D$ and $E$, the parameters are up to you, the structure is up to you.  This paper provides a good insight: https://papers.nips.cc/paper/6802-hiding-images-in-plain-sight-deep-steganography.pdf,  an implementation is found here: https://github.com/fpingham/DeepSteg/blob/master/DeepSteganography.ipynb, https://github.com/Ankit-Dhankhar/deep-steg/blob/master/steg%20net.py, and https://github.com/mr3coi/deepsteg and https://github.com/alexandremuzio/deep-steg and https://github.com/harveyslash/Deep-Steganography....., a blog https://buzzrobot.com/hiding-images-using-ai-deep-steganography-b7726bd58b06
#
# For the network structure, you can borrow the idea from autoencoder for the $E$ part, in that paper, the authors claimed the $E$ part uses 5 layers of convolutional neural networks with 3x3, 4x4, 5x5 patches. The idea is only to approximate the mappings $D$ and $E$, the fully connected network should also work, but convolutional type is cheaper.
#
# A good way to combine DCT (discrete-cosine-transform) to reduce the information first on secret images (bypassing the prep network in the paper). References are easy to find by searching google with DCT keywords.

# %% [markdown]
# ## Optional Task
#
# What if you have two secret images to encrpt, what if there are more. Does LSB work? Does the NN work?

# %% [markdown]
# ## Data set
#
# https://www.kaggle.com/gaz3ll3/optimization-ii-project-3
#
# In order to efficiency, we only consider small pictures, 256x256. If you have problem dealing with 256x256, you can resize them to 128x128 or 64x64.  If you feel the images are too many, you can sample a portion from them as well.
#
# Training and Validation sets are chosen at random (say, 80% and 20%). Each input data will be two images from the training set.
#
# If you are more comfortable with other data sets, it is up to you. Say you can use https://tiny-imagenet.herokuapp.com/ for 64x64 small images.

# %% [markdown]
# ## Metric
#
# In your trainging process for $D$ and $E$, the norm to compare images is the RMSE (root mean squared error), the images are of dimension $N\times N\times 3$, BTW.

# %% [markdown]
# ## Your final result
#
#
# 1.   A writeup on your work, including performance, your work, issues, how do you solve the issues, etc.
# 2.   Test your codes (LSB and NN) against the data set http://r0k.us/graphics/kodak/, each image will be downsize to 256x256 or 128x128 or 64x64 if you trained an NN on smaller images. Report your result in your writeup.
# 3. Code, again, host on github. Submission will be a link.
# 4. If you also tried the optional task, please also report that in your writeup.

# %%
print('Good luck!')
# Out:
# Good luck!

# %% [markdown]
# # First task

# %%
from PIL import Image

# %%
class Steganography(object):

  @staticmethod
  def __int_to_bin(rgb):
    """Convert an integer tuple to a binary (string) tuple.
    :param rgb: An integer tuple (e.g. (220, 110, 96))
    :return: A string tuple (e.g. ("00101010", "11101011", "00010110"))
    """
    r, g, b = rgb
    return ('{0:08b}'.format(r),
        '{0:08b}'.format(g),
        '{0:08b}'.format(b))

  @staticmethod
  def __bin_to_int(rgb):
    """Convert a binary (string) tuple to an integer tuple.
    :param rgb: A string tuple (e.g. ("00101010", "11101011", "00010110"))
    :return: Return an int tuple (e.g. (220, 110, 96))
    """
    r, g, b = rgb
    return (int(r, 2),
        int(g, 2),
        int(b, 2))

  @staticmethod
  def __merge_rgb(rgb1, rgb2):
    """Merge two RGB tuples.
    :param rgb1: A string tuple (e.g. ("00101010", "11101011", "00010110"))
    :param rgb2: Another string tuple
    (e.g. ("00101010", "11101011", "00010110"))
    :return: An integer tuple with the two RGB values merged.
    """
    r1, g1, b1 = rgb1
    r2, g2, b2 = rgb2
    rgb = (r1[:4] + r2[:4],
        g1[:4] + g2[:4],
        b1[:4] + b2[:4])
    return rgb

  @staticmethod
  def merge(img1, img2):
    """Merge two images. The second one will be merged into the first one.
    :param img1: First image
    :param img2: Second image
    :return: A new merged image.
    """

    # Check the images dimensions
    if img2.size[0] > img1.size[0] or img2.size[1] > img1.size[1]:
      raise ValueError('Image 2 should not be larger than Image 1!')

    # Get the pixel map of the two images
    pixel_map1 = img1.load()
    pixel_map2 = img2.load()

    # Create a new image that will be outputted
    new_image = Image.new(img1.mode, img1.size)
    pixels_new = new_image.load()

    for i in range(img1.size[0]):
      for j in range(img1.size[1]):
        rgb1 = Steganography.__int_to_bin(pixel_map1[i, j])

        # Use a black pixel as default
        rgb2 = Steganography.__int_to_bin((0, 0, 0))

        # Check if the pixel map position is valid for the second image
        if i < img2.size[0] and j < img2.size[1]:
          rgb2 = Steganography.__int_to_bin(pixel_map2[i, j])

        # Merge the two pixels and convert it to a integer tuple
        rgb = Steganography.__merge_rgb(rgb1, rgb2)

        pixels_new[i, j] = Steganography.__bin_to_int(rgb)

    return new_image

  @staticmethod
  def unmerge(img):
    """Unmerge an image.
    :param img: The input image.
    :return: The unmerged/extracted image.
    """

    # Load the pixel map
    pixel_map = img.load()

    # Create the new image and load the pixel map
    new_image = Image.new(img.mode, img.size)
    pixels_new = new_image.load()

    # Tuple used to store the image original size
    original_size = img.size

    for i in range(img.size[0]):
      for j in range(img.size[1]):
        # Get the RGB (as a string tuple) from the current pixel
        r, g, b = Steganography.__int_to_bin(pixel_map[i, j])

        # Extract the last 4 bits (corresponding to the hidden image)
        # Concatenate 4 zero bits because we are working with 8 bit
        rgb = (r[4:] + '0000',
            g[4:] + '0000',
            b[4:] + '0000')

        # Convert it to an integer tuple
        pixels_new[i, j] = Steganography.__bin_to_int(rgb)

        # If this is a 'valid' position, store it
        # as the last valid position
        if pixels_new[i, j] != (0, 0, 0):
          original_size = (i + 1, j + 1)

    # Crop the image based on the 'valid' pixels
    new_image = new_image.crop((0, 0, original_size[0], original_size[1]))

    return new_image

# %%
def merge(img1, img2, output):
  merged_image = Steganography.merge(Image.open(img1), Image.open(img2))
  merged_image.save(output)

def unmerge(img, output):
  unmerged_image = Steganography.unmerge(Image.open(img))
  unmerged_image.save(output)

# %% [markdown]
# # Second task

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip gdrive/MyDrive/data.zip
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Archive:  gdrive/MyDrive/data.zip
# replace data/coast/arnat59.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: data/coast/arnat59.jpg
#   inflating: data/coast/art1130.jpg
#   inflating: data/coast/art294.jpg
#   inflating: data/coast/art487.jpg
#   inflating: data/coast/bea1.jpg
#   inflating: data/coast/bea10.jpg
#   inflating: data/coast/bea14.jpg
#   inflating: data/coast/bea2.jpg
#   inflating: data/coast/bea20.jpg
#   inflating: data/coast/bea24.jpg
#   inflating: data/coast/bea26.jpg
#   inflating: data/coast/bea27.jpg
#   inflating: data/coast/bea29.jpg
#   inflating: data/coast/bea3.jpg
#   inflating: data/coast/bea30.jpg
#   inflating: data/coast/bea33.jpg
#   inflating: data/coast/bea38.jpg
#   inflating: data/coast/bea39.jpg
#   inflating: data/coast/bea4.jpg
#   inflating: data/coast/bea5.jpg
#   inflating: data/coast/bea9.jpg
#   inflating: data/coast/cdmc1000.jpg
#   inflating: data/coast/cdmc123.jpg
#   inflating: data/coast/cdmc706.jpg
#   inflating: data/coast/cdmc821.jpg
#   inflating: data/coast/cdmc825.jpg
#   inflating: data/coast/cdmc830.jpg
#   inflating: data/coast/cdmc838.jpg
#   inflating: data/coast/cdmc841.jpg
#   inflating: data/coast/cdmc845.jpg
#   inflating: data/coast/cdmc848.jpg
#   inflating: data/coast/cdmc850.jpg
#   inflating: data/coast/cdmc851.jpg
#   inflating: data/coast/cdmc853.jpg
#   inflating: data/coast/cdmc860.jpg
#   inflating: data/coast/cdmc862.jpg
#   inflating: data/coast/cdmc866.jpg
#   inflating: data/coast/cdmc871.jpg
#   inflating: data/coast/cdmc873.jpg
#   inflating: data/coast/cdmc878.jpg
#   inflating: data/coast/cdmc889.jpg
#   inflating: data/coast/cdmc891.jpg
#   inflating: data/coast/cdmc900.jpg
#   inflating: data/coast/cdmc906.jpg
#   inflating: data/coast/cdmc916.jpg
#   inflating: data/coast/cdmc922.jpg
#   inflating: data/coast/cdmc923.jpg
#   inflating: data/coast/cdmc924.jpg
#   inflating: data/coast/cdmc927.jpg
#   inflating: data/coast/cdmc929.jpg
#   inflating: data/coast/cdmc933.jpg
#   inflating: data/coast/cdmc934.jpg
#   inflating: data/coast/cdmc940.jpg
#   inflating: data/coast/cdmc942.jpg
#   inflating: data/coast/cdmc948.jpg
#   inflating: data/coast/cdmc951.jpg
#   inflating: data/coast/cdmc953.jpg
#   inflating: data/coast/cdmc954.jpg
#   inflating: data/coast/cdmc955.jpg
#   inflating: data/coast/cdmc960.jpg
#   inflating: data/coast/cdmc969.jpg
#   inflating: data/coast/cdmc976.jpg
#   inflating: data/coast/cdmc977.jpg
#   inflating: data/coast/cdmc988.jpg
#   inflating: data/coast/cdmc989.jpg
#   inflating: data/coast/cdmc990.jpg
#   inflating: data/coast/cdmc991.jpg
#   inflating: data/coast/cdmc997.jpg
#   inflating: data/coast/gre637.jpg
#   inflating: data/coast/land100.jpg
#   inflating: data/coast/land108.jpg
#   inflating: data/coast/land111.jpg
#   inflating: data/coast/land112.jpg
#   inflating: data/coast/land113.jpg
#   inflating: data/coast/land114.jpg
#   inflating: data/coast/land115.jpg
#   inflating: data/coast/land237.jpg
#   inflating: data/coast/land253.jpg
#   inflating: data/coast/land258.jpg
#   inflating: data/coast/land261.jpg
#   inflating: data/coast/land277.jpg
#   inflating: data/coast/land296.jpg
#   inflating: data/coast/land302.jpg
#   inflating: data/coast/land309.jpg
#   inflating: data/coast/land334.jpg
#   inflating: data/coast/land339.jpg
#   inflating: data/coast/land340.jpg
#   inflating: data/coast/land341.jpg
#   inflating: data/coast/land367.jpg
#   inflating: data/coast/land368.jpg
#   inflating: data/coast/land369.jpg
#   inflating: data/coast/land370.jpg
#   inflating: data/coast/land371.jpg
#   inflating: data/coast/land372.jpg
#   inflating: data/coast/land374.jpg
#   inflating: data/coast/land386.jpg
#   inflating: data/coast/land480.jpg
#   inflating: data/coast/land623.jpg
#   inflating: data/coast/land812.jpg
#   inflating: data/coast/land897.jpg
#   inflating: data/coast/land902.jpg
#   inflating: data/coast/land924.jpg
#   inflating: data/coast/land946.jpg
#   inflating: data/coast/land951.jpg
#   inflating: data/coast/land954.jpg
#   inflating: data/coast/n122078.jpg
#   inflating: data/coast/n18001.jpg
#   inflating: data/coast/n199065.jpg
#   inflating: data/coast/n199066.jpg
#   inflating: data/coast/n199067.jpg
#   inflating: data/coast/n203004.jpg
#   inflating: data/coast/n203011.jpg
#   inflating: data/coast/n203015.jpg
#   inflating: data/coast/n203030.jpg
#   inflating: data/coast/n203032.jpg
#   inflating: data/coast/n203036.jpg
#   inflating: data/coast/n203037.jpg
#   inflating: data/coast/n203059.jpg
#   inflating: data/coast/n203066.jpg
#   inflating: data/coast/n203069.jpg
#   inflating: data/coast/n203071.jpg
#   inflating: data/coast/n203085.jpg
#   inflating: data/coast/n228047.jpg
#   inflating: data/coast/n228083.jpg
#   inflating: data/coast/n228092.jpg
#   inflating: data/coast/n238045.jpg
#   inflating: data/coast/n241018.jpg
#   inflating: data/coast/n241020.jpg
#   inflating: data/coast/n243003.jpg
#   inflating: data/coast/n243011.jpg
#   inflating: data/coast/n243030.jpg
#   inflating: data/coast/n243057.jpg
#   inflating: data/coast/n243061.jpg
#   inflating: data/coast/n243062.jpg
#   inflating: data/coast/n243063.jpg
#   inflating: data/coast/n286045.jpg
#   inflating: data/coast/n286096.jpg
#   inflating: data/coast/n291008.jpg
#   inflating: data/coast/n291022.jpg
#   inflating: data/coast/n291024.jpg
#   inflating: data/coast/n291030.jpg
#   inflating: data/coast/n291032.jpg
#   inflating: data/coast/n291057.jpg
#   inflating: data/coast/n291061.jpg
#   inflating: data/coast/n291075.jpg
#   inflating: data/coast/n291076.jpg
#   inflating: data/coast/n295011.jpg
#   inflating: data/coast/n295027.jpg
#   inflating: data/coast/n295051.jpg
#   inflating: data/coast/n295068.jpg
#   inflating: data/coast/n295080.jpg
#   inflating: data/coast/n328001.jpg
#   inflating: data/coast/n328036.jpg
#   inflating: data/coast/n328052.jpg
#   inflating: data/coast/n344048.jpg
#   inflating: data/coast/n347041.jpg
#   inflating: data/coast/n347047.jpg
#   inflating: data/coast/n384013.jpg
#   inflating: data/coast/n384026.jpg
#   inflating: data/coast/n384030.jpg
#   inflating: data/coast/n384038.jpg
#   inflating: data/coast/n384092.jpg
#   inflating: data/coast/n384099.jpg
#   inflating: data/coast/n424023.jpg
#   inflating: data/coast/n424079.jpg
#   inflating: data/coast/n424081.jpg
#   inflating: data/coast/n446013.jpg
#   inflating: data/coast/n486055.jpg
#   inflating: data/coast/n603063.jpg
#   inflating: data/coast/n672000.jpg
#   inflating: data/coast/n672003.jpg
#   inflating: data/coast/n672004.jpg
#   inflating: data/coast/n672021.jpg
#   inflating: data/coast/n672031.jpg
#   inflating: data/coast/n672034.jpg
#   inflating: data/coast/n672069.jpg
#   inflating: data/coast/n708004.jpg
#   inflating: data/coast/n708024.jpg
#   inflating: data/coast/n708050.jpg
#   inflating: data/coast/n735016.jpg
#   inflating: data/coast/n736062.jpg
#   inflating: data/coast/n739046.jpg
#   inflating: data/coast/n739047.jpg
#   inflating: data/coast/nat1043.jpg
#   inflating: data/coast/nat1052.jpg
#   inflating: data/coast/nat1053.jpg
#   inflating: data/coast/nat1065.jpg
#   inflating: data/coast/nat1074.jpg
#   inflating: data/coast/nat109.jpg
#   inflating: data/coast/nat1091.jpg
#   inflating: data/coast/nat1099.jpg
#   inflating: data/coast/nat1112.jpg
#   inflating: data/coast/nat1125.jpg
#   inflating: data/coast/nat1146.jpg
#   inflating: data/coast/nat1149.jpg
#   inflating: data/coast/nat1150.jpg
#   inflating: data/coast/nat1151.jpg
#   inflating: data/coast/nat1175.jpg
#   inflating: data/coast/nat1177.jpg
#   inflating: data/coast/nat120.jpg
#   inflating: data/coast/nat1201.jpg
#   inflating: data/coast/nat1208.jpg
#   inflating: data/coast/nat1265.jpg
#   inflating: data/coast/nat167.jpg
#   inflating: data/coast/nat172.jpg
#   inflating: data/coast/nat174.jpg
#   inflating: data/coast/nat186.jpg
#   inflating: data/coast/nat194.jpg
#   inflating: data/coast/nat196.jpg
#   inflating: data/coast/nat202.jpg
#   inflating: data/coast/nat283.jpg
#   inflating: data/coast/nat284.jpg
#   inflating: data/coast/nat285.jpg
#   inflating: data/coast/nat288.jpg
#   inflating: data/coast/nat292.jpg
#   inflating: data/coast/nat293.jpg
#   inflating: data/coast/nat294.jpg
#   inflating: data/coast/nat462.jpg
#   inflating: data/coast/nat472.jpg
#   inflating: data/coast/nat479.jpg
#   inflating: data/coast/nat482.jpg
#   inflating: data/coast/nat491.jpg
#   inflating: data/coast/nat496.jpg
#   inflating: data/coast/nat566.jpg
#   inflating: data/coast/nat601.jpg
#   inflating: data/coast/nat602.jpg
#   inflating: data/coast/nat605.jpg
#   inflating: data/coast/nat639.jpg
#   inflating: data/coast/nat642.jpg
#   inflating: data/coast/nat643.jpg
#   inflating: data/coast/nat667.jpg
#   inflating: data/coast/nat684.jpg
#   inflating: data/coast/nat700.jpg
#   inflating: data/coast/nat705.jpg
#   inflating: data/coast/nat707.jpg
#   inflating: data/coast/nat711.jpg
#   inflating: data/coast/nat736.jpg
#   inflating: data/coast/nat739.jpg
#   inflating: data/coast/nat743.jpg
#   inflating: data/coast/nat745.jpg
#   inflating: data/coast/nat755.jpg
#   inflating: data/coast/nat768.jpg
#   inflating: data/coast/nat770.jpg
#   inflating: data/coast/nat799.jpg
#   inflating: data/coast/nat807.jpg
#   inflating: data/coast/nat810.jpg
#   inflating: data/coast/nat820.jpg
#   inflating: data/coast/nat850.jpg
#   inflating: data/coast/nat865.jpg
#   inflating: data/coast/nat866.jpg
#   inflating: data/coast/nat890.jpg
#   inflating: data/coast/nat893.jpg
#   inflating: data/coast/nat895.jpg
#   inflating: data/coast/nat897.jpg
#   inflating: data/coast/nat899.jpg
#   inflating: data/coast/nat900.jpg
#   inflating: data/coast/nat901.jpg
#   inflating: data/coast/nat904.jpg
#   inflating: data/coast/nat905.jpg
#   inflating: data/coast/nat907.jpg
#   inflating: data/coast/nat908.jpg
#   inflating: data/coast/nat910.jpg
#   inflating: data/coast/nat921.jpg
#   inflating: data/coast/nat956.jpg
#   inflating: data/coast/natu128.jpg
#   inflating: data/coast/natu130.jpg
#   inflating: data/coast/natu131.jpg
#   inflating: data/coast/natu25.jpg
#   inflating: data/coast/natu399.jpg
#   inflating: data/coast/natu408.jpg
#   inflating: data/coast/natu468.jpg
#   inflating: data/coast/natu469.jpg
#   inflating: data/coast/natu473.jpg
#   inflating: data/coast/natu515.jpg
#   inflating: data/coast/natu531.jpg
#   inflating: data/coast/natu604.jpg
#   inflating: data/coast/natu619.jpg
#   inflating: data/coast/natu631.jpg
#   inflating: data/coast/natu638.jpg
#   inflating: data/coast/natu641.jpg
#   inflating: data/coast/natu642.jpg
#   inflating: data/coast/natu643.jpg
#   inflating: data/coast/natu648.jpg
#   inflating: data/coast/natu649.jpg
#   inflating: data/coast/natu666.jpg
#   inflating: data/coast/natu667.jpg
#   inflating: data/coast/natu670.jpg
#   inflating: data/coast/natu702.jpg
#   inflating: data/coast/natu704.jpg
#   inflating: data/coast/natu718.jpg
#   inflating: data/coast/natu772.jpg
#   inflating: data/coast/natu776.jpg
#   inflating: data/coast/natu777.jpg
#   inflating: data/coast/natu789.jpg
#   inflating: data/coast/natu791.jpg
#   inflating: data/coast/natu795.jpg
#   inflating: data/coast/natu798.jpg
#   inflating: data/coast/natu804.jpg
#   inflating: data/coast/natu808.jpg
#   inflating: data/coast/natu811.jpg
#   inflating: data/coast/natu813.jpg
#   inflating: data/coast/natu814.jpg
#   inflating: data/coast/natu815.jpg
#   inflating: data/coast/natu816.jpg
#   inflating: data/coast/natu817.jpg
#   inflating: data/coast/natu818.jpg
#   inflating: data/coast/natu819.jpg
#   inflating: data/coast/natu820.jpg
#   inflating: data/coast/natu822.jpg
#   inflating: data/coast/natu824.jpg
#   inflating: data/coast/natu825.jpg
#   inflating: data/coast/natu826.jpg
#   inflating: data/coast/natu827.jpg
#   inflating: data/coast/natu829.jpg
#   inflating: data/coast/natu830.jpg
#   inflating: data/coast/natu887.jpg
#   inflating: data/coast/natu901.jpg
#   inflating: data/coast/natu908.jpg
#   inflating: data/coast/natu911.jpg
#   inflating: data/coast/natu912.jpg
#   inflating: data/coast/natu919.jpg
#   inflating: data/coast/natu920.jpg
#   inflating: data/coast/natu923.jpg
#   inflating: data/coast/natu938.jpg
#   inflating: data/coast/natu975.jpg
#   inflating: data/coast/natu981.jpg
#   inflating: data/coast/natu986.jpg
#   inflating: data/coast/open13.jpg
#   inflating: data/coast/open60.jpg
#   inflating: data/coast/open62.jpg
#   inflating: data/coast/osun51.jpg
#   inflating: data/coast/osun52.jpg
#   inflating: data/coast/osun54.jpg
#   inflating: data/coast/osun56.jpg
#   inflating: data/coast/sun1.jpg
#   inflating: data/coast/sun11.jpg
#   inflating: data/coast/sun12.jpg
#   inflating: data/coast/sun14.jpg
#   inflating: data/coast/sun15.jpg
#   inflating: data/coast/sun16.jpg
#   inflating: data/coast/sun21.jpg
#   inflating: data/coast/sun22.jpg
#   inflating: data/coast/sun27.jpg
#   inflating: data/coast/sun28.jpg
#   inflating: data/coast/sun3.jpg
#   inflating: data/coast/sun31.jpg
#   inflating: data/coast/sun32.jpg
#   inflating: data/coast/sun33.jpg
#   inflating: data/coast/sun34.jpg
#   inflating: data/coast/sun39.jpg
#   inflating: data/coast/sun4.jpg
#   inflating: data/coast/sun42.jpg
#   inflating: data/coast/sun44.jpg
#   inflating: data/coast/sun45.jpg
#   inflating: data/coast/sun5.jpg
#   inflating: data/coast/sun56.jpg
#   inflating: data/coast/sun57.jpg
#   inflating: data/coast/sun59.jpg
#   inflating: data/coast/sun7.jpg
#   inflating: data/coast/sun8.jpg
#   inflating: data/coast/Thumbs.db
#   inflating: data/forest/art114.jpg
#   inflating: data/forest/bost100.jpg
#   inflating: data/forest/bost101.jpg
#   inflating: data/forest/bost102.jpg
#   inflating: data/forest/bost103.jpg
#   inflating: data/forest/bost190.jpg
#   inflating: data/forest/bost98.jpg
#   inflating: data/forest/cdmc101.jpg
#   inflating: data/forest/cdmc12.jpg
#   inflating: data/forest/cdmc271.jpg
#   inflating: data/forest/cdmc277.jpg
#   inflating: data/forest/cdmc278.jpg
#   inflating: data/forest/cdmc280.jpg
#   inflating: data/forest/cdmc281.jpg
#   inflating: data/forest/cdmc282.jpg
#   inflating: data/forest/cdmc283.jpg
#   inflating: data/forest/cdmc284.jpg
#   inflating: data/forest/cdmc290.jpg
#   inflating: data/forest/cdmc291.jpg
#   inflating: data/forest/cdmc292.jpg
#   inflating: data/forest/cdmc293.jpg
#   inflating: data/forest/cdmc306.jpg
#   inflating: data/forest/cdmc313.jpg
#   inflating: data/forest/cdmc315.jpg
#   inflating: data/forest/cdmc317.jpg
#   inflating: data/forest/cdmc318.jpg
#   inflating: data/forest/cdmc319.jpg
#   inflating: data/forest/cdmc331.jpg
#   inflating: data/forest/cdmc333.jpg
#   inflating: data/forest/cdmc338.jpg
#   inflating: data/forest/cdmc344.jpg
#   inflating: data/forest/cdmc348.jpg
#   inflating: data/forest/cdmc351.jpg
#   inflating: data/forest/cdmc352.jpg
#   inflating: data/forest/cdmc358.jpg
#   inflating: data/forest/cdmc359.jpg
#   inflating: data/forest/cdmc363.jpg
#   inflating: data/forest/cdmc368.jpg
#   inflating: data/forest/cdmc375.jpg
#   inflating: data/forest/cdmc377.jpg
#   inflating: data/forest/cdmc385.jpg
#   inflating: data/forest/cdmc388.jpg
#   inflating: data/forest/cdmc414.jpg
#   inflating: data/forest/cdmc415.jpg
#   inflating: data/forest/cdmc430.jpg
#   inflating: data/forest/cdmc451.jpg
#   inflating: data/forest/cdmc458.jpg
#   inflating: data/forest/cdmc494.jpg
#   inflating: data/forest/cdmc507.jpg
#   inflating: data/forest/cdmc533.jpg
#   inflating: data/forest/cdmc547.jpg
#   inflating: data/forest/cdmc556.jpg
#   inflating: data/forest/cdmc562.jpg
#   inflating: data/forest/for102.jpg
#   inflating: data/forest/for105.jpg
#   inflating: data/forest/for106.jpg
#   inflating: data/forest/for110.jpg
#   inflating: data/forest/for112.jpg
#   inflating: data/forest/for114.jpg
#   inflating: data/forest/for116.jpg
#   inflating: data/forest/for119.jpg
#   inflating: data/forest/for121.jpg
#   inflating: data/forest/for127.jpg
#   inflating: data/forest/for130.jpg
#   inflating: data/forest/for132.jpg
#   inflating: data/forest/for136.jpg
#   inflating: data/forest/for137.jpg
#   inflating: data/forest/for142.jpg
#   inflating: data/forest/for143.jpg
#   inflating: data/forest/for146.jpg
#   inflating: data/forest/for148.jpg
#   inflating: data/forest/for149.jpg
#   inflating: data/forest/for15.jpg
#   inflating: data/forest/for151.jpg
#   inflating: data/forest/for153.jpg
#   inflating: data/forest/for157.jpg
#   inflating: data/forest/for17.jpg
#   inflating: data/forest/for20.jpg
#   inflating: data/forest/for22.jpg
#   inflating: data/forest/for25.jpg
#   inflating: data/forest/for27.jpg
#   inflating: data/forest/for28.jpg
#   inflating: data/forest/for3.jpg
#   inflating: data/forest/for32.jpg
#   inflating: data/forest/for38.jpg
#   inflating: data/forest/for42.jpg
#   inflating: data/forest/for44.jpg
#   inflating: data/forest/for47.jpg
#   inflating: data/forest/for50.jpg
#   inflating: data/forest/for52.jpg
#   inflating: data/forest/for58.jpg
#   inflating: data/forest/for60.jpg
#   inflating: data/forest/for63.jpg
#   inflating: data/forest/for65.jpg
#   inflating: data/forest/for67.jpg
#   inflating: data/forest/for77.jpg
#   inflating: data/forest/for78.jpg
#   inflating: data/forest/for79.jpg
#   inflating: data/forest/for82.jpg
#   inflating: data/forest/for84.jpg
#   inflating: data/forest/for85.jpg
#   inflating: data/forest/for86.jpg
#   inflating: data/forest/for87.jpg
#   inflating: data/forest/for93.jpg
#   inflating: data/forest/for95.jpg
#   inflating: data/forest/for96.jpg
#   inflating: data/forest/land102.jpg
#   inflating: data/forest/land107.jpg
#   inflating: data/forest/land159.jpg
#   inflating: data/forest/land215.jpg
#   inflating: data/forest/land217.jpg
#   inflating: data/forest/land219.jpg
#   inflating: data/forest/land222.jpg
#   inflating: data/forest/land224.jpg
#   inflating: data/forest/land243.jpg
#   inflating: data/forest/land245.jpg
#   inflating: data/forest/land314.jpg
#   inflating: data/forest/land335.jpg
#   inflating: data/forest/land376.jpg
#   inflating: data/forest/land377.jpg
#   inflating: data/forest/land503.jpg
#   inflating: data/forest/land64.jpg
#   inflating: data/forest/land726.jpg
#   inflating: data/forest/land727.jpg
#   inflating: data/forest/land733.jpg
#   inflating: data/forest/land741.jpg
#   inflating: data/forest/land760.jpg
#   inflating: data/forest/land765.jpg
#   inflating: data/forest/land801.jpg
#   inflating: data/forest/land807.jpg
#   inflating: data/forest/land809.jpg
#   inflating: data/forest/land81.jpg
#   inflating: data/forest/land810.jpg
#   inflating: data/forest/land849.jpg
#   inflating: data/forest/land850.jpg
#   inflating: data/forest/land852.jpg
#   inflating: data/forest/land854.jpg
#   inflating: data/forest/land858.jpg
#   inflating: data/forest/land861.jpg
#   inflating: data/forest/land862.jpg
#   inflating: data/forest/land863.jpg
#   inflating: data/forest/land864.jpg
#   inflating: data/forest/land866.jpg
#   inflating: data/forest/land867.jpg
#   inflating: data/forest/land869.jpg
#   inflating: data/forest/land870.jpg
#   inflating: data/forest/land871.jpg
#   inflating: data/forest/land872.jpg
#   inflating: data/forest/land873.jpg
#   inflating: data/forest/land922.jpg
#   inflating: data/forest/moun46.jpg
#   inflating: data/forest/n18075.jpg
#   inflating: data/forest/nat1027.jpg
#   inflating: data/forest/nat1033.jpg
#   inflating: data/forest/nat1088.jpg
#   inflating: data/forest/nat1095.jpg
#   inflating: data/forest/nat1097.jpg
#   inflating: data/forest/nat1127.jpg
#   inflating: data/forest/nat1128.jpg
#   inflating: data/forest/nat1131.jpg
#   inflating: data/forest/nat1184.jpg
#   inflating: data/forest/nat1217.jpg
#   inflating: data/forest/nat1242.jpg
#   inflating: data/forest/nat1248.jpg
#   inflating: data/forest/nat1253.jpg
#   inflating: data/forest/nat1266.jpg
#   inflating: data/forest/nat130.jpg
#   inflating: data/forest/nat145.jpg
#   inflating: data/forest/nat146.jpg
#   inflating: data/forest/nat147.jpg
#   inflating: data/forest/nat162.jpg
#   inflating: data/forest/nat203.jpg
#   inflating: data/forest/nat204.jpg
#   inflating: data/forest/nat205.jpg
#   inflating: data/forest/nat208.jpg
#   inflating: data/forest/nat209.jpg
#   inflating: data/forest/nat210.jpg
#   inflating: data/forest/nat211.jpg
#   inflating: data/forest/nat212.jpg
#   inflating: data/forest/nat219.jpg
#   inflating: data/forest/nat220.jpg
#   inflating: data/forest/nat221.jpg
#   inflating: data/forest/nat223.jpg
#   inflating: data/forest/nat228.jpg
#   inflating: data/forest/nat239.jpg
#   inflating: data/forest/nat260.jpg
#   inflating: data/forest/nat263.jpg
#   inflating: data/forest/nat266.jpg
#   inflating: data/forest/nat281.jpg
#   inflating: data/forest/nat286.jpg
#   inflating: data/forest/nat310.jpg
#   inflating: data/forest/nat312.jpg
#   inflating: data/forest/nat315.jpg
#   inflating: data/forest/nat324.jpg
#   inflating: data/forest/nat325.jpg
#   inflating: data/forest/nat328.jpg
#   inflating: data/forest/nat337.jpg
#   inflating: data/forest/nat338.jpg
#   inflating: data/forest/nat347.jpg
#   inflating: data/forest/nat349.jpg
#   inflating: data/forest/nat354.jpg
#   inflating: data/forest/nat359.jpg
#   inflating: data/forest/nat360.jpg
#   inflating: data/forest/nat361.jpg
#   inflating: data/forest/nat367.jpg
#   inflating: data/forest/nat373.jpg
#   inflating: data/forest/nat398.jpg
#   inflating: data/forest/nat400.jpg
#   inflating: data/forest/nat417.jpg
#   inflating: data/forest/nat442.jpg
#   inflating: data/forest/nat449.jpg
#   inflating: data/forest/nat450.jpg
#   inflating: data/forest/nat451.jpg
#   inflating: data/forest/nat452.jpg
#   inflating: data/forest/nat468.jpg
#   inflating: data/forest/nat470.jpg
#   inflating: data/forest/nat619.jpg
#   inflating: data/forest/nat623.jpg
#   inflating: data/forest/nat697.jpg
#   inflating: data/forest/nat715.jpg
#   inflating: data/forest/nat717.jpg
#   inflating: data/forest/nat719.jpg
#   inflating: data/forest/nat763.jpg
#   inflating: data/forest/nat798.jpg
#   inflating: data/forest/nat835.jpg
#   inflating: data/forest/nat851.jpg
#   inflating: data/forest/nat867.jpg
#   inflating: data/forest/nat946.jpg
#   inflating: data/forest/nat982.jpg
#   inflating: data/forest/natc12.jpg
#   inflating: data/forest/natc13.jpg
#   inflating: data/forest/natc37.jpg
#   inflating: data/forest/natc4.jpg
#   inflating: data/forest/natc49.jpg
#   inflating: data/forest/natc52.jpg
#   inflating: data/forest/natu15.jpg
#   inflating: data/forest/natu158.jpg
#   inflating: data/forest/natu161.jpg
#   inflating: data/forest/natu163.jpg
#   inflating: data/forest/natu164.jpg
#   inflating: data/forest/natu169.jpg
#   inflating: data/forest/natu170.jpg
#   inflating: data/forest/natu172.jpg
#   inflating: data/forest/natu18.jpg
#   inflating: data/forest/natu2.jpg
#   inflating: data/forest/natu26.jpg
#   inflating: data/forest/natu28.jpg
#   inflating: data/forest/natu29.jpg
#   inflating: data/forest/natu308.jpg
#   inflating: data/forest/natu31.jpg
#   inflating: data/forest/natu317.jpg
#   inflating: data/forest/natu322.jpg
#   inflating: data/forest/natu325.jpg
#   inflating: data/forest/natu361.jpg
#   inflating: data/forest/natu396.jpg
#   inflating: data/forest/natu402.jpg
#   inflating: data/forest/natu423.jpg
#   inflating: data/forest/natu424.jpg
#   inflating: data/forest/natu425.jpg
#   inflating: data/forest/natu428.jpg
#   inflating: data/forest/natu430.jpg
#   inflating: data/forest/natu439.jpg
#   inflating: data/forest/natu440.jpg
#   inflating: data/forest/natu441.jpg
#   inflating: data/forest/natu443.jpg
#   inflating: data/forest/natu611.jpg
#   inflating: data/forest/natu634.jpg
#   inflating: data/forest/natu696.jpg
#   inflating: data/forest/natu707.jpg
#   inflating: data/forest/natu72.jpg
#   inflating: data/forest/natu723.jpg
#   inflating: data/forest/natu794.jpg
#   inflating: data/forest/natu846.jpg
#   inflating: data/forest/natu847.jpg
#   inflating: data/forest/natu848.jpg
#   inflating: data/forest/natu850.jpg
#   inflating: data/forest/natu860.jpg
#   inflating: data/forest/natu863.jpg
#   inflating: data/forest/natu866.jpg
#   inflating: data/forest/natu869.jpg
#   inflating: data/forest/natu870.jpg
#   inflating: data/forest/natu871.jpg
#   inflating: data/forest/natu895.jpg
#   inflating: data/forest/natu898.jpg
#   inflating: data/forest/natu913.jpg
#   inflating: data/forest/natu934.jpg
#   inflating: data/forest/natu949.jpg
#   inflating: data/forest/natu977.jpg
#   inflating: data/forest/natu994.jpg
#   inflating: data/forest/sclos11.jpg
#   inflating: data/forest/sclos13.jpg
#   inflating: data/forest/tell51.jpg
#   inflating: data/forest/text102.jpg
#   inflating: data/forest/text103.jpg
#   inflating: data/forest/text105.jpg
#   inflating: data/forest/text106.jpg
#   inflating: data/forest/text107.jpg
#   inflating: data/forest/text11.jpg
#   inflating: data/forest/text111.jpg
#   inflating: data/forest/text119.jpg
#   inflating: data/forest/text122.jpg
#   inflating: data/forest/text124.jpg
#   inflating: data/forest/text13.jpg
#   inflating: data/forest/text20.jpg
#   inflating: data/forest/text21.jpg
#   inflating: data/forest/text26.jpg
#   inflating: data/forest/text28.jpg
#   inflating: data/forest/text29.jpg
#   inflating: data/forest/text35.jpg
#   inflating: data/forest/text38.jpg
#   inflating: data/forest/text39.jpg
#   inflating: data/forest/text40.jpg
#   inflating: data/forest/text41.jpg
#   inflating: data/forest/text42.jpg
#   inflating: data/forest/text43.jpg
#   inflating: data/forest/text44.jpg
#   inflating: data/forest/text45.jpg
#   inflating: data/forest/text46.jpg
#   inflating: data/forest/text47.jpg
#   inflating: data/forest/text48.jpg
#   inflating: data/forest/text49.jpg
#   inflating: data/forest/text50.jpg
#   inflating: data/forest/text63.jpg
#   inflating: data/forest/text75.jpg
#   inflating: data/forest/text81.jpg
#   inflating: data/forest/text90.jpg
#   inflating: data/forest/Thumbs.db
#   inflating: data/forest/urb753.jpg
#   inflating: data/forest/urb767.jpg
#   inflating: data/highway/a836030.jpg
#   inflating: data/highway/a866041.jpg
#   inflating: data/highway/a866042.jpg
#   inflating: data/highway/a866047.jpg
#   inflating: data/highway/a866048.jpg
#   inflating: data/highway/art1134.jpg
#   inflating: data/highway/art1204.jpg
#   inflating: data/highway/art1673.jpg
#   inflating: data/highway/art1674.jpg
#   inflating: data/highway/art1679.jpg
#   inflating: data/highway/art1682.jpg
#   inflating: data/highway/art1693.jpg
#   inflating: data/highway/art1696.jpg
#   inflating: data/highway/art237.jpg
#   inflating: data/highway/art238.jpg
#   inflating: data/highway/art250.jpg
#   inflating: data/highway/art252.jpg
#   inflating: data/highway/art254.jpg
#   inflating: data/highway/art255.jpg
#   inflating: data/highway/art328.jpg
#   inflating: data/highway/art336.jpg
#   inflating: data/highway/art489.jpg
#   inflating: data/highway/art558.jpg
#   inflating: data/highway/art563.jpg
#   inflating: data/highway/art568.jpg
#   inflating: data/highway/art576.jpg
#   inflating: data/highway/art579.jpg
#   inflating: data/highway/art580.jpg
#   inflating: data/highway/art596.jpg
#   inflating: data/highway/art608.jpg
#   inflating: data/highway/art773.jpg
#   inflating: data/highway/art803.jpg
#   inflating: data/highway/art813.jpg
#   inflating: data/highway/art820.jpg
#   inflating: data/highway/art874.jpg
#   inflating: data/highway/art885.jpg
#   inflating: data/highway/art890.jpg
#   inflating: data/highway/bost147.jpg
#   inflating: data/highway/bost148.jpg
#   inflating: data/highway/bost149.jpg
#   inflating: data/highway/bost150.jpg
#   inflating: data/highway/bost151.jpg
#   inflating: data/highway/bost152.jpg
#   inflating: data/highway/bost153.jpg
#   inflating: data/highway/bost154.jpg
#   inflating: data/highway/bost155.jpg
#   inflating: data/highway/bost156.jpg
#   inflating: data/highway/bost157.jpg
#   inflating: data/highway/bost158.jpg
#   inflating: data/highway/bost159.jpg
#   inflating: data/highway/bost160.jpg
#   inflating: data/highway/bost161.jpg
#   inflating: data/highway/bost162.jpg
#   inflating: data/highway/bost163.jpg
#   inflating: data/highway/bost164.jpg
#   inflating: data/highway/bost165.jpg
#   inflating: data/highway/bost166.jpg
#   inflating: data/highway/bost167.jpg
#   inflating: data/highway/bost168.jpg
#   inflating: data/highway/bost169.jpg
#   inflating: data/highway/bost170.jpg
#   inflating: data/highway/bost171.jpg
#   inflating: data/highway/bost172.jpg
#   inflating: data/highway/bost173.jpg
#   inflating: data/highway/bost174.jpg
#   inflating: data/highway/bost175.jpg
#   inflating: data/highway/bost176.jpg
#   inflating: data/highway/bost177.jpg
#   inflating: data/highway/bost178.jpg
#   inflating: data/highway/bost179.jpg
#   inflating: data/highway/bost180.jpg
#   inflating: data/highway/bost181.jpg
#   inflating: data/highway/bost182.jpg
#   inflating: data/highway/bost183.jpg
#   inflating: data/highway/bost184.jpg
#   inflating: data/highway/bost185.jpg
#   inflating: data/highway/bost186.jpg
#   inflating: data/highway/bost187.jpg
#   inflating: data/highway/bost290.jpg
#   inflating: data/highway/bost291.jpg
#   inflating: data/highway/bost292.jpg
#   inflating: data/highway/bost293.jpg
#   inflating: data/highway/bost294.jpg
#   inflating: data/highway/bost295.jpg
#   inflating: data/highway/bost296.jpg
#   inflating: data/highway/bost297.jpg
#   inflating: data/highway/bost298.jpg
#   inflating: data/highway/bost299.jpg
#   inflating: data/highway/bost300.jpg
#   inflating: data/highway/bost301.jpg
#   inflating: data/highway/bost302.jpg
#   inflating: data/highway/bost303.jpg
#   inflating: data/highway/bost304.jpg
#   inflating: data/highway/bost305.jpg
#   inflating: data/highway/bost306.jpg
#   inflating: data/highway/bost307.jpg
#   inflating: data/highway/bost308.jpg
#   inflating: data/highway/bost309.jpg
#   inflating: data/highway/bost310.jpg
#   inflating: data/highway/bost311.jpg
#   inflating: data/highway/bost312.jpg
#   inflating: data/highway/bost313.jpg
#   inflating: data/highway/bost314.jpg
#   inflating: data/highway/bost315.jpg
#   inflating: data/highway/bost316.jpg
#   inflating: data/highway/bost317.jpg
#   inflating: data/highway/bost318.jpg
#   inflating: data/highway/bost319.jpg
#   inflating: data/highway/bost320.jpg
#   inflating: data/highway/bost321.jpg
#   inflating: data/highway/bost322.jpg
#   inflating: data/highway/bost323.jpg
#   inflating: data/highway/bost324.jpg
#   inflating: data/highway/bost325.jpg
#   inflating: data/highway/bost326.jpg
#   inflating: data/highway/bost329.jpg
#   inflating: data/highway/bost330.jpg
#   inflating: data/highway/bost331.jpg
#   inflating: data/highway/bost332.jpg
#   inflating: data/highway/bost334.jpg
#   inflating: data/highway/bost335.jpg
#   inflating: data/highway/bost336.jpg
#   inflating: data/highway/bost374.jpg
#   inflating: data/highway/bost387.jpg
#   inflating: data/highway/bost389.jpg
#   inflating: data/highway/bost392.jpg
#   inflating: data/highway/bost393.jpg
#   inflating: data/highway/bost394.jpg
#   inflating: data/highway/bost395.jpg
#   inflating: data/highway/bost397.jpg
#   inflating: data/highway/bost398.jpg
#   inflating: data/highway/bost402.jpg
#   inflating: data/highway/bost403.jpg
#   inflating: data/highway/gre125.jpg
#   inflating: data/highway/gre140.jpg
#   inflating: data/highway/gre141.jpg
#   inflating: data/highway/gre144.jpg
#   inflating: data/highway/gre145.jpg
#   inflating: data/highway/gre147.jpg
#   inflating: data/highway/gre149.jpg
#   inflating: data/highway/gre153.jpg
#   inflating: data/highway/gre155.jpg
#   inflating: data/highway/gre239.jpg
#   inflating: data/highway/gre275.jpg
#   inflating: data/highway/gre277.jpg
#   inflating: data/highway/gre279.jpg
#   inflating: data/highway/gre30.jpg
#   inflating: data/highway/gre35.jpg
#   inflating: data/highway/gre36.jpg
#   inflating: data/highway/gre37.jpg
#   inflating: data/highway/gre40.jpg
#   inflating: data/highway/gre400.jpg
#   inflating: data/highway/gre402.jpg
#   inflating: data/highway/gre403.jpg
#   inflating: data/highway/gre404.jpg
#   inflating: data/highway/gre406.jpg
#   inflating: data/highway/gre407.jpg
#   inflating: data/highway/gre408.jpg
#   inflating: data/highway/gre409.jpg
#   inflating: data/highway/gre41.jpg
#   inflating: data/highway/gre410.jpg
#   inflating: data/highway/gre411.jpg
#   inflating: data/highway/gre413.jpg
#   inflating: data/highway/gre414.jpg
#   inflating: data/highway/gre415.jpg
#   inflating: data/highway/gre42.jpg
#   inflating: data/highway/gre420.jpg
#   inflating: data/highway/gre426.jpg
#   inflating: data/highway/gre45.jpg
#   inflating: data/highway/gre458.jpg
#   inflating: data/highway/gre459.jpg
#   inflating: data/highway/gre46.jpg
#   inflating: data/highway/gre462.jpg
#   inflating: data/highway/gre466.jpg
#   inflating: data/highway/gre467.jpg
#   inflating: data/highway/gre470.jpg
#   inflating: data/highway/gre472.jpg
#   inflating: data/highway/gre473.jpg
#   inflating: data/highway/gre474.jpg
#   inflating: data/highway/gre475.jpg
#   inflating: data/highway/gre476.jpg
#   inflating: data/highway/gre478.jpg
#   inflating: data/highway/gre479.jpg
#   inflating: data/highway/gre48.jpg
#   inflating: data/highway/gre480.jpg
#   inflating: data/highway/gre481.jpg
#   inflating: data/highway/gre484.jpg
#   inflating: data/highway/gre485.jpg
#   inflating: data/highway/gre491.jpg
#   inflating: data/highway/gre492.jpg
#   inflating: data/highway/gre493.jpg
#   inflating: data/highway/gre50.jpg
#   inflating: data/highway/gre504.jpg
#   inflating: data/highway/gre52.jpg
#   inflating: data/highway/gre525.jpg
#   inflating: data/highway/gre53.jpg
#   inflating: data/highway/gre530.jpg
#   inflating: data/highway/gre532.jpg
#   inflating: data/highway/gre533.jpg
#   inflating: data/highway/gre536.jpg
#   inflating: data/highway/gre537.jpg
#   inflating: data/highway/gre538.jpg
#   inflating: data/highway/gre541.jpg
#   inflating: data/highway/gre55.jpg
#   inflating: data/highway/gre58.jpg
#   inflating: data/highway/gre609.jpg
#   inflating: data/highway/gre610.jpg
#   inflating: data/highway/gre644.jpg
#   inflating: data/highway/gre645.jpg
#   inflating: data/highway/gre646.jpg
#   inflating: data/highway/gre650.jpg
#   inflating: data/highway/gre651.jpg
#   inflating: data/highway/gre656.jpg
#   inflating: data/highway/gre657.jpg
#   inflating: data/highway/gre658.jpg
#   inflating: data/highway/gre659.jpg
#   inflating: data/highway/gre661.jpg
#   inflating: data/highway/gre662.jpg
#   inflating: data/highway/gre678.jpg
#   inflating: data/highway/gre680.jpg
#   inflating: data/highway/gre683.jpg
#   inflating: data/highway/gre684.jpg
#   inflating: data/highway/gre685.jpg
#   inflating: data/highway/land409.jpg
#   inflating: data/highway/land449.jpg
#   inflating: data/highway/land463.jpg
#   inflating: data/highway/land464.jpg
#   inflating: data/highway/n480001.jpg
#   inflating: data/highway/n480020.jpg
#   inflating: data/highway/n480023.jpg
#   inflating: data/highway/n480036.jpg
#   inflating: data/highway/n480045.jpg
#   inflating: data/highway/n480070.jpg
#   inflating: data/highway/nat518.jpg
#   inflating: data/highway/nat520.jpg
#   inflating: data/highway/nat526.jpg
#   inflating: data/highway/nat533.jpg
#   inflating: data/highway/nat542.jpg
#   inflating: data/highway/nat543.jpg
#   inflating: data/highway/nat546.jpg
#   inflating: data/highway/nat550.jpg
#   inflating: data/highway/natu778.jpg
#   inflating: data/highway/natu787.jpg
#   inflating: data/highway/par23.jpg
#   inflating: data/highway/Thumbs.db
#   inflating: data/highway/urb471.jpg
#   inflating: data/highway/urb537.jpg
#   inflating: data/highway/urb545.jpg
#   inflating: data/highway/urb681.jpg
#   inflating: data/highway/urb710.jpg
#   inflating: data/highway/urb713.jpg
#   inflating: data/highway/urb714.jpg
#   inflating: data/highway/urb715.jpg
#   inflating: data/highway/urb716.jpg
#   inflating: data/highway/urb720.jpg
#   inflating: data/highway/urb743.jpg
#   inflating: data/highway/urb744.jpg
#   inflating: data/highway/urb754.jpg
#   inflating: data/highway/urb759.jpg
#   inflating: data/highway/urb784.jpg
#   inflating: data/highway/urb962.jpg
#   inflating: data/inside_city/a0004.jpg
#   inflating: data/inside_city/a0010.jpg
#   inflating: data/inside_city/a111017.jpg
#   inflating: data/inside_city/a129035.jpg
#   inflating: data/inside_city/a129048.jpg
#   inflating: data/inside_city/a129053.jpg
#   inflating: data/inside_city/a140032.jpg
#   inflating: data/inside_city/a212024.jpg
#   inflating: data/inside_city/a212025.jpg
#   inflating: data/inside_city/a212052.jpg
#   inflating: data/inside_city/a223049.jpg
#   inflating: data/inside_city/a248032.jpg
#   inflating: data/inside_city/a248045.jpg
#   inflating: data/inside_city/a379017.jpg
#   inflating: data/inside_city/a385019.jpg
#   inflating: data/inside_city/a385047.jpg
#   inflating: data/inside_city/a385073.jpg
#   inflating: data/inside_city/a385075.jpg
#   inflating: data/inside_city/a462055.jpg
#   inflating: data/inside_city/a463022.jpg
#   inflating: data/inside_city/a463024.jpg
#   inflating: data/inside_city/a463036.jpg
#   inflating: data/inside_city/a463070.jpg
#   inflating: data/inside_city/a463092.jpg
#   inflating: data/inside_city/a48009.jpg
#   inflating: data/inside_city/a487026.jpg
#   inflating: data/inside_city/a632023.jpg
#   inflating: data/inside_city/a683008.jpg
#   inflating: data/inside_city/a683031.jpg
#   inflating: data/inside_city/a79054.jpg
#   inflating: data/inside_city/a804060.jpg
#   inflating: data/inside_city/a805046.jpg
#   inflating: data/inside_city/a805052.jpg
#   inflating: data/inside_city/a805082.jpg
#   inflating: data/inside_city/a805091.jpg
#   inflating: data/inside_city/a806018.jpg
#   inflating: data/inside_city/a807036.jpg
#   inflating: data/inside_city/a807066.jpg
#   inflating: data/inside_city/a808082.jpg
#   inflating: data/inside_city/a808091.jpg
#   inflating: data/inside_city/a855084.jpg
#   inflating: data/inside_city/art1026.jpg
#   inflating: data/inside_city/art1037.jpg
#   inflating: data/inside_city/art1039.jpg
#   inflating: data/inside_city/art104.jpg
#   inflating: data/inside_city/art1044.jpg
#   inflating: data/inside_city/art1058.jpg
#   inflating: data/inside_city/art1082.jpg
#   inflating: data/inside_city/art1102.jpg
#   inflating: data/inside_city/art1110.jpg
#   inflating: data/inside_city/art1117.jpg
#   inflating: data/inside_city/art1125.jpg
#   inflating: data/inside_city/art1135.jpg
#   inflating: data/inside_city/art1156.jpg
#   inflating: data/inside_city/art1158.jpg
#   inflating: data/inside_city/art1161.jpg
#   inflating: data/inside_city/art1164.jpg
#   inflating: data/inside_city/art1165.jpg
#   inflating: data/inside_city/art1167.jpg
#   inflating: data/inside_city/art1185.jpg
#   inflating: data/inside_city/art1186.jpg
#   inflating: data/inside_city/art1231.jpg
#   inflating: data/inside_city/art1258.jpg
#   inflating: data/inside_city/art1269.jpg
#   inflating: data/inside_city/art1277.jpg
#   inflating: data/inside_city/art1291.jpg
#   inflating: data/inside_city/art136.jpg
#   inflating: data/inside_city/art1363.jpg
#   inflating: data/inside_city/art1364.jpg
#   inflating: data/inside_city/art1366.jpg
#   inflating: data/inside_city/art1406.jpg
#   inflating: data/inside_city/art1443.jpg
#   inflating: data/inside_city/art1486.jpg
#   inflating: data/inside_city/art1496.jpg
#   inflating: data/inside_city/art1528.jpg
#   inflating: data/inside_city/art1586.jpg
#   inflating: data/inside_city/art1594.jpg
#   inflating: data/inside_city/art1597.jpg
#   inflating: data/inside_city/art1598.jpg
#   inflating: data/inside_city/art1604.jpg
#   inflating: data/inside_city/art1633.jpg
#   inflating: data/inside_city/art165.jpg
#   inflating: data/inside_city/art1651.jpg
#   inflating: data/inside_city/art1664.jpg
#   inflating: data/inside_city/art1677.jpg
#   inflating: data/inside_city/art1678.jpg
#   inflating: data/inside_city/art20.jpg
#   inflating: data/inside_city/art30.jpg
#   inflating: data/inside_city/art50.jpg
#   inflating: data/inside_city/art545.jpg
#   inflating: data/inside_city/art551.jpg
#   inflating: data/inside_city/art569.jpg
#   inflating: data/inside_city/art612.jpg
#   inflating: data/inside_city/art620.jpg
#   inflating: data/inside_city/art622.jpg
#   inflating: data/inside_city/art625.jpg
#   inflating: data/inside_city/art626.jpg
#   inflating: data/inside_city/art628.jpg
#   inflating: data/inside_city/art635.jpg
#   inflating: data/inside_city/art637.jpg
#   inflating: data/inside_city/art638.jpg
#   inflating: data/inside_city/art641.jpg
#   inflating: data/inside_city/art642.jpg
#   inflating: data/inside_city/art643.jpg
#   inflating: data/inside_city/art644.jpg
#   inflating: data/inside_city/art646.jpg
#   inflating: data/inside_city/art649.jpg
#   inflating: data/inside_city/art650.jpg
#   inflating: data/inside_city/art654.jpg
#   inflating: data/inside_city/art656.jpg
#   inflating: data/inside_city/art659.jpg
#   inflating: data/inside_city/art661.jpg
#   inflating: data/inside_city/art666.jpg
#   inflating: data/inside_city/art669.jpg
#   inflating: data/inside_city/art673.jpg
#   inflating: data/inside_city/art676.jpg
#   inflating: data/inside_city/art677.jpg
#   inflating: data/inside_city/art681.jpg
#   inflating: data/inside_city/art690.jpg
#   inflating: data/inside_city/art692.jpg
#   inflating: data/inside_city/art695.jpg
#   inflating: data/inside_city/art700.jpg
#   inflating: data/inside_city/art727.jpg
#   inflating: data/inside_city/art735.jpg
#   inflating: data/inside_city/art738.jpg
#   inflating: data/inside_city/art770.jpg
#   inflating: data/inside_city/art785.jpg
#   inflating: data/inside_city/art786.jpg
#   inflating: data/inside_city/art787.jpg
#   inflating: data/inside_city/art795.jpg
#   inflating: data/inside_city/art819.jpg
#   inflating: data/inside_city/art827.jpg
#   inflating: data/inside_city/art829.jpg
#   inflating: data/inside_city/art831.jpg
#   inflating: data/inside_city/art847.jpg
#   inflating: data/inside_city/art871.jpg
#   inflating: data/inside_city/art892.jpg
#   inflating: data/inside_city/art901.jpg
#   inflating: data/inside_city/art902.jpg
#   inflating: data/inside_city/art903.jpg
#   inflating: data/inside_city/art904.jpg
#   inflating: data/inside_city/art917.jpg
#   inflating: data/inside_city/art920.jpg
#   inflating: data/inside_city/art922.jpg
#   inflating: data/inside_city/art942.jpg
#   inflating: data/inside_city/art947.jpg
#   inflating: data/inside_city/artc3.jpg
#   inflating: data/inside_city/artc8.jpg
#   inflating: data/inside_city/bost109.jpg
#   inflating: data/inside_city/bost141.jpg
#   inflating: data/inside_city/bost191.jpg
#   inflating: data/inside_city/bost27.jpg
#   inflating: data/inside_city/bost29.jpg
#   inflating: data/inside_city/bost42.jpg
#   inflating: data/inside_city/bost44.jpg
#   inflating: data/inside_city/bost55.jpg
#   inflating: data/inside_city/bost79.jpg
#   inflating: data/inside_city/bost85.jpg
#   inflating: data/inside_city/boston149.jpg
#   inflating: data/inside_city/boston232.jpg
#   inflating: data/inside_city/boston245.jpg
#   inflating: data/inside_city/boston247.jpg
#   inflating: data/inside_city/boston262.jpg
#   inflating: data/inside_city/boston282.jpg
#   inflating: data/inside_city/boston29.jpg
#   inflating: data/inside_city/boston305.jpg
#   inflating: data/inside_city/boston340.jpg
#   inflating: data/inside_city/boston361.jpg
#   inflating: data/inside_city/boston369.jpg
#   inflating: data/inside_city/boston383.jpg
#   inflating: data/inside_city/boston57.jpg
#   inflating: data/inside_city/boston80.jpg
#   inflating: data/inside_city/boston92.jpg
#   inflating: data/inside_city/city21.jpg
#   inflating: data/inside_city/city84.jpg
#   inflating: data/inside_city/enc3.jpg
#   inflating: data/inside_city/gre102.jpg
#   inflating: data/inside_city/gre19.jpg
#   inflating: data/inside_city/gre197.jpg
#   inflating: data/inside_city/gre207.jpg
#   inflating: data/inside_city/gre22.jpg
#   inflating: data/inside_city/gre249.jpg
#   inflating: data/inside_city/gre262.jpg
#   inflating: data/inside_city/gre270.jpg
#   inflating: data/inside_city/gre286.jpg
#   inflating: data/inside_city/gre287.jpg
#   inflating: data/inside_city/gre290.jpg
#   inflating: data/inside_city/gre303.jpg
#   inflating: data/inside_city/gre304.jpg
#   inflating: data/inside_city/gre314.jpg
#   inflating: data/inside_city/gre318.jpg
#   inflating: data/inside_city/gre446.jpg
#   inflating: data/inside_city/gre511.jpg
#   inflating: data/inside_city/gre641.jpg
#   inflating: data/inside_city/gre9.jpg
#   inflating: data/inside_city/gre94.jpg
#   inflating: data/inside_city/gre98.jpg
#   inflating: data/inside_city/hous1.jpg
#   inflating: data/inside_city/hous106.jpg
#   inflating: data/inside_city/hous109.jpg
#   inflating: data/inside_city/hous114.jpg
#   inflating: data/inside_city/hous120.jpg
#   inflating: data/inside_city/hous121.jpg
#   inflating: data/inside_city/hous126.jpg
#   inflating: data/inside_city/hous13.jpg
#   inflating: data/inside_city/hous130.jpg
#   inflating: data/inside_city/hous14.jpg
#   inflating: data/inside_city/hous15.jpg
#   inflating: data/inside_city/hous18.jpg
#   inflating: data/inside_city/hous19.jpg
#   inflating: data/inside_city/hous22.jpg
#   inflating: data/inside_city/hous24.jpg
#   inflating: data/inside_city/hous28.jpg
#   inflating: data/inside_city/hous35.jpg
#   inflating: data/inside_city/hous36.jpg
#   inflating: data/inside_city/hous37.jpg
#   inflating: data/inside_city/hous39.jpg
#   inflating: data/inside_city/hous40.jpg
#   inflating: data/inside_city/hous50.jpg
#   inflating: data/inside_city/hous52.jpg
#   inflating: data/inside_city/hous60.jpg
#   inflating: data/inside_city/hous64.jpg
#   inflating: data/inside_city/hous68.jpg
#   inflating: data/inside_city/hous70.jpg
#   inflating: data/inside_city/hous71.jpg
#   inflating: data/inside_city/hous77.jpg
#   inflating: data/inside_city/hous79.jpg
#   inflating: data/inside_city/hous83.jpg
#   inflating: data/inside_city/hous85.jpg
#   inflating: data/inside_city/hous87.jpg
#   inflating: data/inside_city/hous90.jpg
#   inflating: data/inside_city/hous93.jpg
#   inflating: data/inside_city/hous96.jpg
#   inflating: data/inside_city/hous97.jpg
#   inflating: data/inside_city/par104.jpg
#   inflating: data/inside_city/par128.jpg
#   inflating: data/inside_city/par129.jpg
#   inflating: data/inside_city/par136.jpg
#   inflating: data/inside_city/par139.jpg
#   inflating: data/inside_city/par173.jpg
#   inflating: data/inside_city/par180.jpg
#   inflating: data/inside_city/par181.jpg
#   inflating: data/inside_city/par186.jpg
#   inflating: data/inside_city/par189.jpg
#   inflating: data/inside_city/par194.jpg
#   inflating: data/inside_city/par40.jpg
#   inflating: data/inside_city/Thumbs.db
#   inflating: data/inside_city/urb108.jpg
#   inflating: data/inside_city/urb114.jpg
#   inflating: data/inside_city/urb121.jpg
#   inflating: data/inside_city/urb123.jpg
#   inflating: data/inside_city/urb130.jpg
#   inflating: data/inside_city/urb224.jpg
#   inflating: data/inside_city/urb245.jpg
#   inflating: data/inside_city/urb250.jpg
# ...
#   inflating: data/tallbuilding/a212017.jpg
#   inflating: data/tallbuilding/a212018.jpg
#   inflating: data/tallbuilding/a212026.jpg
#   inflating: data/tallbuilding/a212033.jpg
#   inflating: data/tallbuilding/a212044.jpg
#   inflating: data/tallbuilding/a212055.jpg
#   inflating: data/tallbuilding/a223039.jpg
#   inflating: data/tallbuilding/a244009.jpg
#   inflating: data/tallbuilding/a244030.jpg
#   inflating: data/tallbuilding/a244040.jpg
#   inflating: data/tallbuilding/a244043.jpg
#   inflating: data/tallbuilding/a244046.jpg
#   inflating: data/tallbuilding/a244068.jpg
#   inflating: data/tallbuilding/a244069.jpg
#   inflating: data/tallbuilding/a244081.jpg
#   inflating: data/tallbuilding/a248018.jpg
#   inflating: data/tallbuilding/a279032.jpg
#   inflating: data/tallbuilding/a279033.jpg
#   inflating: data/tallbuilding/a372007.jpg
#   inflating: data/tallbuilding/a438011.jpg
#   inflating: data/tallbuilding/a438038.jpg
#   inflating: data/tallbuilding/a438046.jpg
#   inflating: data/tallbuilding/a462003.jpg
#   inflating: data/tallbuilding/a462018.jpg
#   inflating: data/tallbuilding/a462022.jpg
#   inflating: data/tallbuilding/a462023.jpg
#   inflating: data/tallbuilding/a462025.jpg
#   inflating: data/tallbuilding/a462050.jpg
#   inflating: data/tallbuilding/a462057.jpg
#   inflating: data/tallbuilding/a462093.jpg
#   inflating: data/tallbuilding/a463068.jpg
#   inflating: data/tallbuilding/a484066.jpg
#   inflating: data/tallbuilding/a487002.jpg
#   inflating: data/tallbuilding/a487039.jpg
#   inflating: data/tallbuilding/a487041.jpg
#   inflating: data/tallbuilding/a487045.jpg
#   inflating: data/tallbuilding/a487047.jpg
#   inflating: data/tallbuilding/a487049.jpg
#   inflating: data/tallbuilding/a487053.jpg
#   inflating: data/tallbuilding/a487056.jpg
#   inflating: data/tallbuilding/a487061.jpg
#   inflating: data/tallbuilding/a487062.jpg
#   inflating: data/tallbuilding/a487063.jpg
#   inflating: data/tallbuilding/a487065.jpg
#   inflating: data/tallbuilding/a487066.jpg
#   inflating: data/tallbuilding/a487067.jpg
#   inflating: data/tallbuilding/a487069.jpg
#   inflating: data/tallbuilding/a487070.jpg
#   inflating: data/tallbuilding/a487074.jpg
#   inflating: data/tallbuilding/a487082.jpg
#   inflating: data/tallbuilding/a487085.jpg
#   inflating: data/tallbuilding/a487086.jpg
#   inflating: data/tallbuilding/a487087.jpg
#   inflating: data/tallbuilding/a487092.jpg
#   inflating: data/tallbuilding/a487098.jpg
#   inflating: data/tallbuilding/a526065.jpg
#   inflating: data/tallbuilding/a526079.jpg
#   inflating: data/tallbuilding/a538076.jpg
#   inflating: data/tallbuilding/a562064.jpg
#   inflating: data/tallbuilding/a562066.jpg
#   inflating: data/tallbuilding/a588087.jpg
#   inflating: data/tallbuilding/a632011.jpg
#   inflating: data/tallbuilding/a632016.jpg
#   inflating: data/tallbuilding/a636015.jpg
#   inflating: data/tallbuilding/a803053.jpg
#   inflating: data/tallbuilding/a804050.jpg
#   inflating: data/tallbuilding/a804068.jpg
#   inflating: data/tallbuilding/a804071.jpg
#   inflating: data/tallbuilding/a805043.jpg
#   inflating: data/tallbuilding/a805044.jpg
#   inflating: data/tallbuilding/a805085.jpg
#   inflating: data/tallbuilding/a805096.jpg
#   inflating: data/tallbuilding/a806011.jpg
#   inflating: data/tallbuilding/a806016.jpg
#   inflating: data/tallbuilding/a806037.jpg
#   inflating: data/tallbuilding/a807024.jpg
#   inflating: data/tallbuilding/a807065.jpg
#   inflating: data/tallbuilding/a808015.jpg
#   inflating: data/tallbuilding/a808075.jpg
#   inflating: data/tallbuilding/a808081.jpg
#   inflating: data/tallbuilding/a808090.jpg
#   inflating: data/tallbuilding/a812029.jpg
#   inflating: data/tallbuilding/a812069.jpg
#   inflating: data/tallbuilding/archi28.jpg
#   inflating: data/tallbuilding/archi296.jpg
#   inflating: data/tallbuilding/archi317.jpg
#   inflating: data/tallbuilding/archi337.jpg
#   inflating: data/tallbuilding/archi603.jpg
#   inflating: data/tallbuilding/archi611.jpg
#   inflating: data/tallbuilding/archi615.jpg
#   inflating: data/tallbuilding/archi621.jpg
#   inflating: data/tallbuilding/archi628.jpg
#   inflating: data/tallbuilding/archi629.jpg
#   inflating: data/tallbuilding/archi67.jpg
#   inflating: data/tallbuilding/archi71.jpg
#   inflating: data/tallbuilding/archi85.jpg
#   inflating: data/tallbuilding/archi95.jpg
#   inflating: data/tallbuilding/art1001.jpg
#   inflating: data/tallbuilding/art1004.jpg
#   inflating: data/tallbuilding/art101.jpg
#   inflating: data/tallbuilding/art1011.jpg
#   inflating: data/tallbuilding/art1012.jpg
#   inflating: data/tallbuilding/art1015.jpg
#   inflating: data/tallbuilding/art1017.jpg
#   inflating: data/tallbuilding/art1022.jpg
#   inflating: data/tallbuilding/art1027.jpg
#   inflating: data/tallbuilding/art1028.jpg
#   inflating: data/tallbuilding/art106.jpg
#   inflating: data/tallbuilding/art1183.jpg
#   inflating: data/tallbuilding/art1228.jpg
#   inflating: data/tallbuilding/art1310.jpg
#   inflating: data/tallbuilding/art1316.jpg
#   inflating: data/tallbuilding/art1346.jpg
#   inflating: data/tallbuilding/art1349.jpg
#   inflating: data/tallbuilding/art1350.jpg
#   inflating: data/tallbuilding/art1351.jpg
#   inflating: data/tallbuilding/art1352.jpg
#   inflating: data/tallbuilding/art1353.jpg
#   inflating: data/tallbuilding/art1357.jpg
#   inflating: data/tallbuilding/art1370.jpg
#   inflating: data/tallbuilding/art1387.jpg
#   inflating: data/tallbuilding/art1390.jpg
#   inflating: data/tallbuilding/art1392.jpg
#   inflating: data/tallbuilding/art1393.jpg
#   inflating: data/tallbuilding/art1413.jpg
#   inflating: data/tallbuilding/art1474.jpg
#   inflating: data/tallbuilding/art1481.jpg
#   inflating: data/tallbuilding/art1482.jpg
#   inflating: data/tallbuilding/art1483.jpg
#   inflating: data/tallbuilding/art15.jpg
#   inflating: data/tallbuilding/art1506.jpg
#   inflating: data/tallbuilding/art1538.jpg
#   inflating: data/tallbuilding/art1546.jpg
#   inflating: data/tallbuilding/art1549.jpg
#   inflating: data/tallbuilding/art1556.jpg
#   inflating: data/tallbuilding/art1558.jpg
#   inflating: data/tallbuilding/art1589.jpg
#   inflating: data/tallbuilding/art1593.jpg
#   inflating: data/tallbuilding/art1616.jpg
#   inflating: data/tallbuilding/art1617.jpg
#   inflating: data/tallbuilding/art1618.jpg
#   inflating: data/tallbuilding/art1619.jpg
#   inflating: data/tallbuilding/art1624.jpg
#   inflating: data/tallbuilding/art1684.jpg
#   inflating: data/tallbuilding/art1707.jpg
#   inflating: data/tallbuilding/art1708.jpg
#   inflating: data/tallbuilding/art1711.jpg
#   inflating: data/tallbuilding/art1712.jpg
#   inflating: data/tallbuilding/art1713.jpg
#   inflating: data/tallbuilding/art1716.jpg
#   inflating: data/tallbuilding/art1717.jpg
#   inflating: data/tallbuilding/art1718.jpg
#   inflating: data/tallbuilding/art1719.jpg
#   inflating: data/tallbuilding/art172.jpg
#   inflating: data/tallbuilding/art1720.jpg
#   inflating: data/tallbuilding/art1722.jpg
#   inflating: data/tallbuilding/art1725.jpg
#   inflating: data/tallbuilding/art1727.jpg
#   inflating: data/tallbuilding/art1728.jpg
#   inflating: data/tallbuilding/art1729.jpg
#   inflating: data/tallbuilding/art1732.jpg
#   inflating: data/tallbuilding/art1747.jpg
#   inflating: data/tallbuilding/art1748.jpg
#   inflating: data/tallbuilding/art1749.jpg
#   inflating: data/tallbuilding/art1750.jpg
#   inflating: data/tallbuilding/art1751.jpg
#   inflating: data/tallbuilding/art1754.jpg
#   inflating: data/tallbuilding/art1756.jpg
#   inflating: data/tallbuilding/art181.jpg
#   inflating: data/tallbuilding/art183.jpg
#   inflating: data/tallbuilding/art185.jpg
#   inflating: data/tallbuilding/art188.jpg
#   inflating: data/tallbuilding/art218.jpg
#   inflating: data/tallbuilding/art219.jpg
#   inflating: data/tallbuilding/art221.jpg
#   inflating: data/tallbuilding/art224.jpg
#   inflating: data/tallbuilding/art232.jpg
#   inflating: data/tallbuilding/art260.jpg
#   inflating: data/tallbuilding/art296.jpg
#   inflating: data/tallbuilding/art306.jpg
#   inflating: data/tallbuilding/art309.jpg
#   inflating: data/tallbuilding/art315.jpg
#   inflating: data/tallbuilding/art326.jpg
#   inflating: data/tallbuilding/art332.jpg
#   inflating: data/tallbuilding/art350.jpg
#   inflating: data/tallbuilding/art352.jpg
#   inflating: data/tallbuilding/art360.jpg
#   inflating: data/tallbuilding/art373.jpg
#   inflating: data/tallbuilding/art385.jpg
#   inflating: data/tallbuilding/art391.jpg
#   inflating: data/tallbuilding/art392.jpg
#   inflating: data/tallbuilding/art424.jpg
#   inflating: data/tallbuilding/art425.jpg
#   inflating: data/tallbuilding/art426.jpg
#   inflating: data/tallbuilding/art430.jpg
#   inflating: data/tallbuilding/art435.jpg
#   inflating: data/tallbuilding/art442.jpg
#   inflating: data/tallbuilding/art446.jpg
#   inflating: data/tallbuilding/art447.jpg
#   inflating: data/tallbuilding/art452.jpg
#   inflating: data/tallbuilding/art453.jpg
#   inflating: data/tallbuilding/art457.jpg
#   inflating: data/tallbuilding/art459.jpg
#   inflating: data/tallbuilding/art473.jpg
#   inflating: data/tallbuilding/art523.jpg
#   inflating: data/tallbuilding/art525.jpg
#   inflating: data/tallbuilding/art527.jpg
#   inflating: data/tallbuilding/art528.jpg
#   inflating: data/tallbuilding/art554.jpg
#   inflating: data/tallbuilding/art56.jpg
#   inflating: data/tallbuilding/art572.jpg
#   inflating: data/tallbuilding/art589.jpg
#   inflating: data/tallbuilding/art617.jpg
#   inflating: data/tallbuilding/art733.jpg
#   inflating: data/tallbuilding/art736.jpg
#   inflating: data/tallbuilding/art840.jpg
#   inflating: data/tallbuilding/art853.jpg
#   inflating: data/tallbuilding/art854.jpg
#   inflating: data/tallbuilding/art899.jpg
#   inflating: data/tallbuilding/art900.jpg
#   inflating: data/tallbuilding/art925.jpg
#   inflating: data/tallbuilding/art936.jpg
#   inflating: data/tallbuilding/art943.jpg
#   inflating: data/tallbuilding/art945.jpg
#   inflating: data/tallbuilding/art979.jpg
#   inflating: data/tallbuilding/bost341.jpg
#   inflating: data/tallbuilding/bost390.jpg
#   inflating: data/tallbuilding/boston210.jpg
#   inflating: data/tallbuilding/city1.jpg
#   inflating: data/tallbuilding/city10.jpg
#   inflating: data/tallbuilding/city12.jpg
#   inflating: data/tallbuilding/city14.jpg
#   inflating: data/tallbuilding/city15.jpg
#   inflating: data/tallbuilding/city22.jpg
#   inflating: data/tallbuilding/city24.jpg
#   inflating: data/tallbuilding/city29.jpg
#   inflating: data/tallbuilding/city30.jpg
#   inflating: data/tallbuilding/city31.jpg
#   inflating: data/tallbuilding/city32.jpg
#   inflating: data/tallbuilding/city36.jpg
#   inflating: data/tallbuilding/city38.jpg
#   inflating: data/tallbuilding/city4.jpg
#   inflating: data/tallbuilding/city41.jpg
#   inflating: data/tallbuilding/city47.jpg
#   inflating: data/tallbuilding/city5.jpg
#   inflating: data/tallbuilding/city50.jpg
#   inflating: data/tallbuilding/city56.jpg
#   inflating: data/tallbuilding/city60.jpg
#   inflating: data/tallbuilding/city65.jpg
#   inflating: data/tallbuilding/city7.jpg
#   inflating: data/tallbuilding/city70.jpg
#   inflating: data/tallbuilding/city8.jpg
#   inflating: data/tallbuilding/city83.jpg
#   inflating: data/tallbuilding/city86.jpg
#   inflating: data/tallbuilding/exp19.jpg
#   inflating: data/tallbuilding/gre5.jpg
#   inflating: data/tallbuilding/natu472.jpg
#   inflating: data/tallbuilding/sky1.jpg
#   inflating: data/tallbuilding/sky10.jpg
#   inflating: data/tallbuilding/sky13.jpg
#   inflating: data/tallbuilding/sky17.jpg
#   inflating: data/tallbuilding/sky21.jpg
#   inflating: data/tallbuilding/sky22.jpg
#   inflating: data/tallbuilding/sky25.jpg
#   inflating: data/tallbuilding/sky26.jpg
#   inflating: data/tallbuilding/sky3.jpg
#   inflating: data/tallbuilding/sky30.jpg
#   inflating: data/tallbuilding/sky34.jpg
#   inflating: data/tallbuilding/sky35.jpg
#   inflating: data/tallbuilding/sky37.jpg
#   inflating: data/tallbuilding/sky38.jpg
#   inflating: data/tallbuilding/sky42.jpg
#   inflating: data/tallbuilding/sky43.jpg
#   inflating: data/tallbuilding/sky7.jpg
#   inflating: data/tallbuilding/Thumbs.db
#   inflating: data/tallbuilding/urb133.jpg
#   inflating: data/tallbuilding/urb153.jpg
#   inflating: data/tallbuilding/urb159.jpg
#   inflating: data/tallbuilding/urb246.jpg
#   inflating: data/tallbuilding/urb325.jpg
#   inflating: data/tallbuilding/urb390.jpg
#   inflating: data/tallbuilding/urb391.jpg
#   inflating: data/tallbuilding/urb398.jpg
#   inflating: data/tallbuilding/urb492.jpg
#   inflating: data/tallbuilding/urb522.jpg
#   inflating: data/tallbuilding/urb529.jpg
#   inflating: data/tallbuilding/urb726.jpg
#   inflating: data/tallbuilding/urb731.jpg
#   inflating: data/tallbuilding/urb733.jpg
#   inflating: data/tallbuilding/urb777.jpg
#   inflating: data/tallbuilding/urb792.jpg
#   inflating: data/tallbuilding/urb893.jpg
#   inflating: data/tallbuilding/urb899.jpg
#   inflating: data/tallbuilding/urb906.jpg
#   inflating: data/tallbuilding/urb907.jpg
#   inflating: data/tallbuilding/urb911.jpg
#   inflating: data/tallbuilding/urb914.jpg
#   inflating: data/tallbuilding/urb923.jpg
#   inflating: data/tallbuilding/urb974.jpg
#   inflating: data/tallbuilding/urb988.jpg
#   inflating: data/tallbuilding/urb992.jpg
#   inflating: data/tallbuilding/urban1003.jpg
#   inflating: data/tallbuilding/urban1009.jpg
#   inflating: data/tallbuilding/urban1015.jpg
#   inflating: data/tallbuilding/urban1028.jpg
#   inflating: data/tallbuilding/urban1038.jpg
#   inflating: data/tallbuilding/urban1044.jpg
#   inflating: data/tallbuilding/urban1048.jpg
#   inflating: data/tallbuilding/urban1056.jpg
#   inflating: data/tallbuilding/urban1057.jpg
#   inflating: data/tallbuilding/urban1059.jpg
#   inflating: data/tallbuilding/urban1064.jpg
#   inflating: data/tallbuilding/urban1081.jpg
#   inflating: data/tallbuilding/urban1110.jpg
#   inflating: data/tallbuilding/urban1124.jpg
#   inflating: data/tallbuilding/urban1126.jpg
#   inflating: data/tallbuilding/urban1141.jpg
#   inflating: data/tallbuilding/urban1150.jpg
#   inflating: data/tallbuilding/urban1152.jpg
#   inflating: data/tallbuilding/urban1158.jpg
#   inflating: data/tallbuilding/urban1172.jpg
#   inflating: data/tallbuilding/urban1177.jpg
#   inflating: data/tallbuilding/urban1193.jpg
#   inflating: data/tallbuilding/urban1202.jpg
#   inflating: data/tallbuilding/urban1210.jpg
#   inflating: data/tallbuilding/urban15.jpg
#   inflating: data/tallbuilding/urban157.jpg
#   inflating: data/tallbuilding/urban158.jpg
#   inflating: data/tallbuilding/urban16.jpg
#   inflating: data/tallbuilding/urban166.jpg
#   inflating: data/tallbuilding/urban167.jpg
#   inflating: data/tallbuilding/urban171.jpg
#   inflating: data/tallbuilding/urban22.jpg
#   inflating: data/tallbuilding/urban24.jpg
#   inflating: data/tallbuilding/urban28.jpg
#   inflating: data/tallbuilding/urban3.jpg
#   inflating: data/tallbuilding/urban4.jpg
#   inflating: data/tallbuilding/urban445.jpg
#   inflating: data/tallbuilding/urban45.jpg
#   inflating: data/tallbuilding/urban596.jpg
#   inflating: data/tallbuilding/urban649.jpg
#   inflating: data/tallbuilding/urban693.jpg
#   inflating: data/tallbuilding/urban73.jpg
#   inflating: data/tallbuilding/urban732.jpg
#   inflating: data/tallbuilding/urban744.jpg
#   inflating: data/tallbuilding/urban745.jpg
#   inflating: data/tallbuilding/urban749.jpg
#   inflating: data/tallbuilding/urban780.jpg
#   inflating: data/tallbuilding/urban787.jpg
#   inflating: data/tallbuilding/urban828.jpg
#   inflating: data/tallbuilding/urban846.jpg
#   inflating: data/tallbuilding/urban979.jpg
#   inflating: data/tallbuilding/urban982.jpg
#   inflating: data/tallbuilding/urban983.jpg
#   inflating: data/tallbuilding/urban987.jpg
#   inflating: data/tallbuilding/urban989.jpg
#   inflating: data/tallbuilding/urban991.jpg

# %%
import io
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import IPython
from scipy import fftpack
from itertools import islice
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import pickle
from torchvision import datasets, utils
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle

# %%
# Hyper Parameters
num_epochs = 110 # 设置模型训练的周期数
batch_size = 32 # 设置模型训练的batch size
learning_rate = 0.001 # 学习率
beta = 1

data_path = "/content/data" # 数据集的路径

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

checkpoints_path = "models" # 模型保存的路径
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu') # 判断是否支持GPU训练
if not os.path.exists(checkpoints_path): os.mkdir(checkpoints_path) # 判断模型保存的文件夹是否存在，如果不，那就创建一个

# %%
# 定义损失函数
def customized_loss(S_prime1, S_prime2, C_prime, S1, S2, C, B):
  ''' Calculates loss specified on the paper.'''
  
  loss_cover = torch.nn.functional.mse_loss(C_prime, C) # 实际覆盖图像和生成的覆盖图像之间的标准 MSE
  loss_secret1 = torch.nn.functional.mse_loss(S_prime1, S1) # 实际加密图像和生成解密图像之间的 MSE
  loss_secret2 = torch.nn.functional.mse_loss(S_prime2, S2) # 实际加密图像和生成解密图像之间的 MSE
  loss_all = loss_cover + B * loss_secret1 + B*loss_secret2 # B就是前面那个beta是一个超参数，用来控制应该重建多少信息
  return loss_all, loss_cover, loss_secret1+loss_secret2

  # 这个添加高斯噪声的函数
def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    # noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    noise = torch.nn.init.normal_(torch.Tensor(tensor.size()), 0, 0.1).cuda()
    return (tensor + noise).clone().detach().requires_grad_(True)

# %%
# 预备网络用于准备隐藏加密图像，主要用途当加密图像（尺寸MM）小于载体图像（NN）的情况下，预备网络将加密图像的大小逐步增加到覆盖图像的大小，从而将保密图像的比特位分布到整个NN像素上。其次
# 与所有尺寸的隐藏图像相关的更重要的目的是将基于颜色的像素转换为更有用的特征，以便简洁地编码图像
# 这里主要是三个分别3x3,4x4, 5x5不同大小的卷积核, 并且每个卷积层有50个filters
class PrepNet(nn.Module):
    def __init__(self):
        super(PrepNet, self).__init__()
        
        # Preparation Network
        # 由于输入图像的是彩色图片，也就是图像是3维的，因此p1到p3的第一个ConvNet layer是输入通道数是3，输出是50，然后接下来第二个layer的输入和输出通道数都是50，每个layer后面都是使用relu激活函数，并padding补齐保持feature map的w和h与输入的图像w和h一致
        self.p1 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU()
        )
        
        self.p2 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU()
        )

        self.p3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )
        # p4到p6的第一个layer的输入通道数是150，输出是50，主要是因为我们将p1到p3的特征拼接成一个具有150个通道的feature maps，然后第二个layer的输入和输出通道数均是50，也使用了relu激活函数，并padding补齐保持feature map的w和h与输入的图像w和h一致
        self.p4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU()
        )
        
        self.p5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU()
        )

        self.p6 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )

    def forward(self, S):
        
        p1 = self.p1(S)
        p2 = self.p2(S)
        p3 = self.p3(S)
        x = torch.cat((p1, p2, p3), 1)
        p4 = self.p4(x)
        p5 = self.p5(x)
        p6 = self.p6(x)
        y = torch.cat((p4, p5, p6), 1) # 拼接p4到p6的feature map并输出
        return y

# %%
# 解码网络： 将预备网络的输出和载体图像作为输入，并创建容器图像
# 与准备网络类似，这里同样使用了三个分别3x3,4x4, 5x5不同大小的卷积核, 并且每个卷积层有50个filters，但唯一不同的是该网络是将预备网络的输出和载体图像拼接起来作为输入
# 去除载体图像，显示加密图像
class EncoderNet(nn.Module):

    def __init__(self):
        super(EncoderNet, self).__init__()
        self.e1 = nn.Sequential(
            nn.Conv2d(303, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
        )

        self.e2 = nn.Sequential(
            nn.Conv2d(303, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
        )

        self.e3 = nn.Sequential(
            nn.Conv2d(303, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
        )

        self.e4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )

        self.e5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )

        self.e6 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )

        self.out1 = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0)
        )

        self.out2 = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0)
        )

    # 编码网络的模型结构与准备网络的模型结构类型，主要的不同有两点，第一个由于这个同时将预备网络的输出和载体图像作为输入，所以这个地方的e1到e3的第一个layer的输入通道数是153，以及最后使用一个卷积核为1的卷积层，完成最后的嵌入，也就是生成被隐藏信息的图像
    # 同时生成与被隐藏信息图像一样的高斯分布的噪声，其均值为0，标准差为0.1
    def forward(self, x):
        e1 = self.e1(x)
        e2 = self.e2(x)
        e3 = self.e3(x)
        x = torch.cat((e1, e2, e3), 1)
        e4 = self.e4(x)
        e5 = self.e5(x)
        e6 = self.e6(x)
        x = torch.cat((e4, e5, e6), 1)
        y1 = self.out1(x)
        y2 = self.out2(x)
        y_noise1 = gaussian(y1.data, 0, 0.1)
        y_noise2 = gaussian(y2.data, 0, 0.1)
        return y1, y_noise1, y_noise2

# %%
# 接收载密容器图像，恢复载体图像
class DecoderNet(nn.Module):
    def __init__(self):
        super(DecoderNet, self).__init__()

        self.d1 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU()
        )
        
        self.d2 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU()
        )

        self.d3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )

        self.d4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU()
        )
        
        self.d5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU()
        )

        self.d6 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU()
        )
        self.final = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0)
        )
    # 解码网络与编码网络类似，主要是用来解密图像
    def forward(self, x):
        d1 = self.d1(x)
        d2 = self.d2(x)
        d3 = self.d3(x)
        x = torch.cat((d1, d2, d3), 1)
        d4 = self.d4(x)
        d5 = self.d5(x)
        d6 = self.d6(x)
        x = torch.cat((d4, d5, d6), 1)
        y = self.final(x)
        return y

# %%
# 这个模型就是以上三个模块实现
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.p1 = PrepNet()
        self.p2 = PrepNet()
        self.e = EncoderNet()
        self.d = DecoderNet()

    def forward(self, S1, S2, C):
        S1 = self.p1(S1)
        S2 = self.p1(S2)
        x = torch.cat((S1, S2, C), 1)
        x1, x_noise1, x_noise2 = self.e(x)
        y1 = self.d(x_noise1)
        y2 = self.d(x_noise2)
        return x, y1, y2

# %%
model = Model().cuda() # 将模型挂载在GPU上

# %%
# 加载图片，主要是将文件的路径保存在一个list
def load_data(data_path):
    data_list = []
    for root, dirs, files in os.walk(data_path):
        for file in files:
            if file.endswith(".jpg"):
                data_list.append(os.path.join(root, file))
    return data_list

# %%
data_list = load_data(data_path)
shuffle(data_list) # 将以上返回的图片路径的list打乱
data_list = np.array(data_list)
# 将数据进行切分，80%：20% 训练集和测试集
train_data = data_list[0:int(0.8*len(data_list))]
test_data = data_list[int(0.8*len(data_list)):]

# %%
# 对数据集进行转换，主要有，由于图像的大小是256x256x3，但是为了计算效率所以将图像resize成128，这样一次性就可以加载更多的图片
train_transforms = transforms.Compose([
        transforms.Resize(64),
        transforms.RandomCrop(64),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])

test_transforms = transforms.Compose([
        transforms.Resize(64),
        transforms.RandomCrop(64),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])

# %%
# 这个地方就是加载图片保存在内存中
class MyDataset(Dataset):

    def __init__(self, imgs, transform=None):
        super(MyDataset, self).__init__()   #对继承自父类的属性进行初始化
        self.imgs = imgs
        self.transform = transform

    def __getitem__(self, index):
        img_path = self.imgs[index]
        img = Image.open(img_path)
        if self.transform is not None:
            data = self.transform(img)
        else:
            img = np.asarray(img)
            data = torch.from_numpy(img)
        return data
    
    def __len__(self):
        '''返回数据集的长度'''
        return len(self.imgs)

# %%
# 数据集加载以及设置数据加载的方式
train_dataset = MyDataset(train_data, train_transforms)
test_dataset = MyDataset(test_data, test_transforms)
#Creates training set
train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, num_workers=0, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        test_dataset, batch_size=2, num_workers=0, 
        pin_memory=True, shuffle=False, drop_last=True)

# %%
# 开始训练网络
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        model.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data = train_batch
            data = data.cuda()

            # Saves secret images and secret covers
            train_covers = data[:21]
            train_secrets1 = data[21:42]
            train_secrets2 = data[42:63]
            
            # Creates variable from secret and cover images
            train_secrets1 = train_secrets1.clone().detach().requires_grad_(True)
            train_secrets2 = train_secrets2.clone().detach().requires_grad_(True)
            train_covers = train_covers.clone().detach().requires_grad_(True)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output1, train_output2 = model(train_secrets1, train_secrets2, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output1, train_output2, train_hidden, train_secrets1, train_secrets2, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            # print(train_loss.data)
            train_losses.append(torch.Tensor.item(train_loss.data))
            loss_history.append(torch.Tensor.item(train_loss.data))
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), (torch.Tensor.item(train_loss.data)), torch.Tensor.item(train_loss_cover.data), torch.Tensor.item(train_loss_secret.data)))
        
        if epoch+1 % 10 == 0:
            torch.save(model.state_dict(), checkpoints_path+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return model, mean_train_loss, loss_history

# %%
model, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-131-8ef18b3b230c> in <module>()
# ----> 1 model, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
#
# <ipython-input-130-0363b2ef91ff> in train_model(train_loader, beta, learning_rate)
#      31             # Forward + Backward + Optimize
#      32             optimizer.zero_grad()
# ---> 33             train_hidden, train_output1, train_output2 = model(train_secrets1, train_secrets2, train_covers)
#      34
#      35             # Calculate loss and perform backprop
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-122-87bb68ecbcf5> in forward(self, S1, S2, C)
#       9
#      10     def forward(self, S1, S2, C):
# ---> 11         S1 = self.p1(S1)
#      12         S2 = self.p1(S2)
#      13         x = torch.cat((S1, S2, C), 1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-71-cf290c4e5d60> in forward(self, S)
#      57         x = torch.cat((p1, p2, p3), 1)
#      58         p4 = self.p4(x)
# ---> 59         p5 = self.p5(x)
#      60         p6 = self.p6(x)
#      61         y = torch.cat((p4, p5, p6), 1) # 拼接p4到p6的feature map并输出
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     438                             _pair(0), self.dilation, self.groups)
#     439         return F.conv2d(input, weight, bias, self.stride,
# --> 440                         self.padding, self.dilation, self.groups)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 11.17 GiB total capacity; 10.56 GiB already allocated; 15.81 MiB free; 10.71 GiB reserved in total by PyTorch)

# %%
model.load_state_dict(torch.load(checkpoints_path+'Epoch N110.pkl'))

# %%
# 反归一化只要是用来显示图片内容
def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image
# 显示图片的函数
def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

# %%
# Switch to evaluate mode
model.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data = test_batch.cuda()
    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images

    test_secret = test_secret.clone().detach().requires_grad_(False)
    test_cover = test_cover.clone().detach().requires_grad_(False)
    # Compute output
    test_hidden, test_output = model(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
    test_secret = test_secret.to('cpu')
    test_cover = test_cover.to('cpu')
    test_hidden, test_output = test_hidden.cpu(), test_output.cpu() 
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)
#     test_secret.data, test_output.data, test_cover.data, test_hidden.data,test_output.data = 
    if idx % 100 == 0:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(torch.Tensor.item(test_loss.data), torch.Tensor.item(loss_secret.data), torch.Tensor.item(loss_cover.data)))

        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data,]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(torch.Tensor.item(test_loss.data))
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
